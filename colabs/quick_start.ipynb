# %% [markdown]
# # Quick start

# %% [markdown]
# Welcome to the quick start guide for AlphaGenome! The goal of this tutorial
# notebook is to quickly get you started with using the model and making
# predictions.

# %% [markdown]
# ```{tip}
# Open this tutorial in Google Colab for interactive viewing.
# ```

# %%
# @title Install AlphaGenome

# @markdown Run this cell to install AlphaGenome.
from IPython.display import clear_output
! pip install alphagenome
clear_output()

# %% [markdown]
# ## Imports

# %%
from alphagenome import colab_utils
from alphagenome.data import gene_annotation
from alphagenome.data import genome
from alphagenome.data import transcript as transcript_utils
from alphagenome.interpretation import ism
from alphagenome.models import dna_client
from alphagenome.models import variant_scorers
from alphagenome.visualization import plot_components
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# ## Predict outputs for a DNA sequence

# %% [markdown]
# AlphaGenome is a model that makes predictions from DNA sequences. Let's load it
# up:

# %% [markdown]
# ```{tip}
# If using Google Colab, store your key in "Secrets" for persistent access across sessions (see [installation](https://www.alphagenomedocs.com/installation.html#google-colab)). Otherwise, `dna_client.create` can take the API key directly.
# ```

# %%
dna_model = dna_client.create(colab_utils.get_api_key())

# %% [markdown]
# he model can make predictions for the following
# [output types](https://www.alphagenomedocs.com/exploring_model_metadata.html):

# %%
[output.name for output in dna_client.OutputType]
# Out:
# ['ATAC',
#  'CAGE',
#  'DNASE',
#  'RNA_SEQ',
#  'CHIP_HISTONE',
#  'CHIP_TF',
#  'SPLICE_SITES',
#  'SPLICE_SITE_USAGE',
#  'SPLICE_JUNCTIONS',
#  'CONTACT_MAPS',
#  'PROCAP']

# %% [markdown]
# AlphaGenome predicts multiple 'tracks' per output type, covering a wide variety
# of tissues and cell-types. However, predictions can be made efficiently for
# subsets of interest.
#
# Here is how to make DNase-seq predictions (as specified by `OutputType`) in a
# subset of tracks corresponding to lung tissue (as specified by `ontology_terms`)
# for a DNA sequence of length 1Mb:
#
# *Note: We use ontology terms from standardized biological sources like UBERON
# (for anatomy) and the Cell Ontology (CL) to provide consistent and widely
# recognized classifications for tissue and cell types.*

# %%
output = dna_model.predict_sequence(
    sequence='GATTACA'.center(
        dna_client.SEQUENCE_LENGTH_1MB, 'N'
    ),  # Pad to valid sequence length.
    requested_outputs=[dna_client.OutputType.DNASE],
    ontology_terms=['UBERON:0002048'],  # Lung.
)

# %% [markdown]
# The `output` object contains predictions for all the different requested output
# types (in this case, only output type `DNASE`). Predictions for genomic tracks
# are stored inside a `TrackData` object:

# %%
dnase = output.dnase
type(dnase)
# Out:
# alphagenome.data.track_data.TrackData

# %% [markdown]
# `TrackData` objects have the following components:

# %% [markdown]
# <a href="https://services.google.com/fh/files/misc/trackdata.png"><img src="https://services.google.com/fh/files/misc/trackdata.png" alt="trackdata" border="0" height=500></a>

# %% [markdown]
# The predictions of shape `(sequence_length, num_tracks)` are stored in
# `.values`:

# %%
print(dnase.values.shape)

dnase.values
# Out:
# (1048576, 1)
# array([[0.00187683],
#        [0.00177765],
#        [0.00177765],
#        ...,
#        [0.0019989 ],
#        [0.00292969],
#        [0.0039978 ]], shape=(1048576, 1), dtype=float32)

# %% [markdown]
# And the corresponding metadata describing each of the tracks is stored in
# `.metadata`:

# %%
dnase.metadata
# Out:
#                        name strand  ... genetically_modified nonzero_mean
# 0  UBERON:0002048 DNase-seq      .  ...                False     0.427505
#
# [1 rows x 11 columns]

# %% [markdown]
# In this case, there is only one output track, so the track metadata returns only
# 1 row.
#
# The track metadata is especially useful when requesting predictions for multiple
# tissues or cell-types, and when dealing with stranded assays (which are assays
# with separate readouts for the two DNA strands, such as CAGE and RNA-seq):

# %%
output = dna_model.predict_sequence(
    sequence='GATTACA'.center(
        dna_client.SEQUENCE_LENGTH_1MB, 'N'
    ),  # Pad to valid sequence length.
    requested_outputs=[
        dna_client.OutputType.CAGE,
        dna_client.OutputType.DNASE,
    ],
    ontology_terms=[
        'UBERON:0002048',  # Lung.
        'UBERON:0000955',  # Brain.
    ],
)

print(f'DNASE predictions shape: {output.dnase.values.shape}')
print(f'CAGE predictions shape: {output.cage.values.shape}')
# Out:
# DNASE predictions shape: (1048576, 2)
# CAGE predictions shape: (1048576, 4)

# %% [markdown]
# Notice that in this example, we requested predictions for 2 assays and 2
# ontology terms simultaneously.
#
# The CAGE track metadata describes the strand and tissue of each of the 4
# predicted tracks (2 per DNA strand):

# %%
output.cage.metadata
# Out:
#                    name strand  ... data_source nonzero_mean
# 0  hCAGE UBERON:0000955      +  ...      fantom    28.432245
# 1  hCAGE UBERON:0002048      +  ...      fantom    30.655853
# 2  hCAGE UBERON:0000955      -  ...      fantom    28.432245
# 3  hCAGE UBERON:0002048      -  ...      fantom    30.655853
#
# [4 rows x 8 columns]

# %% [markdown]
# See the
# [output metadata documentation](https://www.alphagenomedocs.com/exploring_model_metadata.html)
# for more information on the output types and output shapes. For the mapping
# between tissue names (e.g. 'brain' -> 'UBERON:0000955') and ontology terms, see
# this [tutorial](tissue_ontology_mapping.ipynb).

# %% [markdown]
# ## Predict outputs for a genome interval (reference genome)

# %% [markdown]
# We made predictions of RNA-seq on the genomic interval of 1MB of chromosome 11 around *BDNF* in 'substantia nigra development'. *BDNF* plays an important role in the survival of dopaminergic cells in the substantia nigra and synaptic plasticity
#
# We first load up a GTF file containing gene and transcript locations as
# annotated by GENCODE (more information on GTF format
# [here](https://www.gencodegenes.org/pages/data_format.html)):

# %%
# The GTF file contains information on the location of all trancripts.
# Note that we use genome assembly hg38 for human.
gtf = pd.read_feather(
    'https://storage.googleapis.com/alphagenome/reference/gencode/'
    'hg38/gencode.v46.annotation.gtf.gz.feather'
)

# Set up transcript extractors using the information in the GTF file.
# Mane select transcripts consists of of one curated transcript per locus.
gtf_transcripts = gene_annotation.filter_protein_coding(gtf)
gtf_transcripts = gene_annotation.filter_to_mane_select_transcript(gtf_transcripts)
transcript_extractor = transcript_utils.TranscriptExtractor(gtf_transcripts)

# %% [markdown]
# And then fetch the gene's location as a `genome.Interval` object by passing
# either its `gene_symbol` (HGNC naming convention) or ENSEMBL `gene_id`:

# %%
interval = gene_annotation.get_gene_interval(gtf, gene_symbol='BDNF')
interval
# Out:
# Interval(chromosome='chr11', start=27654892, end=27722058, strand='-', name='BDNF')

# %% [markdown]
# We can resize it to a length compatible with the model:

# %%
interval = interval.resize(dna_client.SEQUENCE_LENGTH_1MB)

# %% [markdown]
# The `.resize()` method adjusts the interval to the specified width by expanding
# (or contracting) around its original center. Note that
# `dna_model.predict_interval()` interprets this resizing as an expansion of the
# actual genomic sequence rather than padding tokens.

# %%
interval.width
# Out:
# 1048576

# %% [markdown]
# See the
# [essential commands documentation](https://www.alphagenomedocs.com/colabs/essential_commands.html)
# for more handy commands like `resize`.
#
# Note that AlphaGenome supports the following input sequence lengths:

# %%
dna_client.SUPPORTED_SEQUENCE_LENGTHS.keys()
# Out:
# dict_keys(['SEQUENCE_LENGTH_16KB', 'SEQUENCE_LENGTH_100KB', 'SEQUENCE_LENGTH_500KB', 'SEQUENCE_LENGTH_1MB'])

# %% [markdown]
# We can now make predictions using our interval:

# %%
output = dna_model.predict_interval(
    interval=interval,
    requested_outputs=[dna_client.OutputType.RNA_SEQ],
    ontology_terms=['UBERON:0002038'],
)  # sustantia nigra development.

output.rna_seq.values.shape
# Out:
# (1048576, 1)

# %% [markdown]
# In general, you can have multiple tracks for a given ontology term. In this
# case, we have 1 RNA-seq tracks for the tissue "substantia nigra".
#
# Let's visualise these predictions. It's helpful visualise gene transcripts
# alongside the predicted tracks, so we extract them here:

# %%
transcripts = transcript_extractor.extract(interval)
print(f'Extracted {len(transcripts)} transcripts in this interval.')
# Out:
# Extracted 6 transcripts in this interval.

# %% [markdown]
# We also provide a
# [visualization basics guide](https://www.alphagenomedocs.com/visualization_library_basics.html)
# that integrates nicely with `TrackData` and other objects returned by the model
# API.

# %%
plot_components.plot(
    components=[
        plot_components.TranscriptAnnotation(transcripts),
        plot_components.Tracks(output.rna_seq),
    ],
    interval=output.rna_seq.interval,
)

plt.show()

# %% [markdown]
# This plot visualises the 1 predicted RNA-seq tracks and also marks the location
# of the MANE select transcript per gene in the 1MB region.
#
# We can zoom in to the middle of the plot by resizing the interval:

# %%
plot_components.plot(
    components=[
        plot_components.TranscriptAnnotation(
            transcripts, fig_height=0.1
        ),
        plot_components.Tracks(output.rna_seq),
    ],
    interval=output.rna_seq.interval.resize(2**16),
)

plt.show()

# %% [markdown]
# We can see that it only predicted one track. The negative strand where the expression correlates with exons. Also, a peak in introns.
#
# For more detail on the visualization library, please refer to the
# [visualization basics guide](https://www.alphagenomedocs.com/visualization_library_basics.html)
# and
# [library documentation](https://www.alphagenomedocs.com/api/visualization.html).

# %% [markdown]
# ## Predict variant effects

# %% [markdown]
# We can predict the effect of a variant on a specific output type and tissue by
# making predictions for the reference (REF) and alternative (ALT) allele
# sequences.
#
# We specify the variant by defining a `genome.Variant` object. The specific
# variant below is a known variant affecting gene expression in colon tissue:

# %%
variant1 = genome.Variant(
    chromosome='chr11',
    position=27693531,
    reference_bases='C',  # Can differ from the true reference genome base.
    alternate_bases='T',
)

# %% [markdown]
# Next, we define the interval over which to make the REF and ALT predictions. A
# quick way to get a `genome.Interval` from a `genome.Variant` is by calling
# `.reference_interval`, which we can resize to a model-compatible sequence
# length:

# %%
interval1 = variant1.reference_interval.resize(dna_client.SEQUENCE_LENGTH_1MB)

# %% [markdown]
# We then use `predict_variant` to get the REF and ALT RNA-seq predictions in the
# interval for "substantia nigra" tissue (`UBERON:0002038`):

# %%
variant1_output = dna_model.predict_variant(
    interval=interval1,
    variant=variant1,
    requested_outputs=[dna_client.OutputType.RNA_SEQ],
    ontology_terms=['UBERON:0002038'],
)  # substantia nigra.

# %% [markdown]
# We can plot the predicted REF and ALT values as a single plot and zoom in on the
# affected gene to better visualise the variant's effect on gene expression:

# %%
transcripts = transcript_extractor.extract(interval1)

plot_components.plot(
    [
        plot_components.TranscriptAnnotation(transcripts),
        plot_components.OverlaidTracks(
            tdata={
                'REF': variant1_output.reference.rna_seq,
                'ALT': variant1_output.alternate.rna_seq,
            },
            colors={'REF': 'dimgrey', 'ALT': 'red'},
        ),
    ],
    interval=variant1_output.reference.rna_seq.interval.resize(2**16),
    # Annotate the location of the variant as a vertical line.
    annotations=[plot_components.VariantAnnotation([variant1], alpha=0.8)],
)
plt.show()

# %% [markdown]
# Buscamos la siguiente variante. chr11:27708375:G:A_A

# %%
variant2 = genome.Variant(
    chromosome='chr11',
    position=27708375,
    reference_bases='G',  # Can differ from the true reference genome base.
    alternate_bases='A',
)

# %%
interval2 = variant2.reference_interval.resize(dna_client.SEQUENCE_LENGTH_1MB)

# %%
variant2_output = dna_model.predict_variant(
    interval=interval2,
    variant=variant2,
    requested_outputs=[dna_client.OutputType.RNA_SEQ],
    ontology_terms=['UBERON:0002038'],
)  # substantia nigra.

# %%
transcripts = transcript_extractor.extract(interval2)

plot_components.plot(
    [
        plot_components.TranscriptAnnotation(transcripts),
        plot_components.OverlaidTracks(
            tdata={
                'REF': variant2_output.reference.rna_seq,
                'ALT': variant2_output.alternate.rna_seq,
            },
            colors={'REF': 'dimgrey', 'ALT': 'red'},
        ),
    ],
    interval=variant2_output.reference.rna_seq.interval.resize(2**16),
    # Annotate the location of the variant as a vertical line.
    annotations=[plot_components.VariantAnnotation([variant2], alpha=0.8)],
)
plt.show()

# %% [markdown]
# We see that the ALT alleles (base 'A' at position 27708375) is not associated with higher or lower expression in BDNF. It is possible to adjust the y axes limits, see
# [visualization basics](https://www.alphagenomedocs.com/visualization_library_basics.html#visualization-library-basics)
# and
# [library documentation](https://www.alphagenomedocs.com/api/visualization.html).

# %% [markdown]
# ## Scoring the effect of a genetic variant

# %% [markdown]
# Scoring the effect of a genetic variant involves making predictions for the REF
# and ALT sequences and aggregating the track signal. This is implemented in
# `score_variant`, which uses specific `variant_scorer` configs for aggregation.
#
# We provide a set of recommended variant scoring configurations as a dictionary
# (`variant_scorers.RECOMMENDED_VARIANT_SCORERS`), covering all output types,
# which we have assessed for their performance at domain-specific tasks. See the
# [variant scoring documentation](https://www.alphagenomedocs.com/variant_scoring.html)
# for more information. Here is a quick demo:

# %%
variant_scorer = variant_scorers.RECOMMENDED_VARIANT_SCORERS['RNA_SEQ']

variant_scores = dna_model.score_variant(
    interval=interval1, variant=variant1, variant_scorers=[variant_scorer]
)

# %% [markdown]
# The returned `variant_scores` is a list of length 1 because we only specified 1
# scorer:

# %%
len(variant_scores)
# Out:
# 1

# %% [markdown]
# The actual scores per variant are in `AnnData` format, which is a way of
# annotating data (the numerical scores) with additional information about the
# rows and columns.

# %%
variant_scores = variant_scores[0]
variant_scores
# Out:
# AnnData object with n_obs × n_vars = 20 × 371
#     obs: 'gene_id', 'strand', 'gene_name', 'gene_type'
#     var: 'name', 'strand', 'Assay title', 'ontology_curie', 'biosample_name', 'biosample_type', 'biosample_life_stage', 'gtex_tissue', 'data_source', 'endedness', 'genetically_modified', 'nonzero_mean'
#     uns: 'interval', 'variant', 'variant_scorer'
#     layers: 'quantiles', None (.X)

# %% [markdown]
# `AnnData` objects have the following components:

# %% [markdown]
# <a href="https://services.google.com/fh/files/misc/anndata.png"><img src="https://services.google.com/fh/files/misc/anndata.png" alt="anndata" border="0" height=500></a>

# %% [markdown]
# We have a variant effect score for each of the 20 genes in the interval and each
# of the 371 unique `RNA_SEQ` tracks:

# %%
variant_scores.X.shape
# Out:
# (20, 371)

# %% [markdown]
# We can access information on the 20 genes using `.obs`. Here are just first 5 genes:

# %%
variant_scores.obs.head()
# Out:
#               gene_id strand gene_name       gene_type
# 0  ENSG00000109881.17      -    CCDC34  protein_coding
# 1   ENSG00000121621.7      -    KIF18A  protein_coding
# 2  ENSG00000148943.12      -     LIN7C  protein_coding
# 3  ENSG00000169519.21      +   METTL15  protein_coding
# 4  ENSG00000176697.20      -      BDNF  protein_coding

# %% [markdown]
# Note that if you are using a variant scorer that is not gene-specific (i.e., a
# `variant_scorers.CenterMaskScorer`), then `variant_scores.X` would have shape
# `(1, 667)` and there will be no gene metadata available since there is no
# concept of genes in this scenario.
#
# The description of each track is accessed using `.var` (this is the same
# dataframe as the output metadata, but is included alongside the variant scores
# for convenience):

# %%
variant_scores.var
# Out:
#                                                   name strand  \
# 0                        CL:0000047 polyA plus RNA-seq      .
# 1                             CL:0000062 total RNA-seq      .
# 2                        CL:0000084 polyA plus RNA-seq      .
# 3                             CL:0000084 total RNA-seq      .
# 4                             CL:0000115 total RNA-seq      .
# ..                                                 ...    ...
# 366                  UBERON:0018115 polyA plus RNA-seq      .
# 367                  UBERON:0018116 polyA plus RNA-seq      .
# 368                  UBERON:0018117 polyA plus RNA-seq      .
# 369                  UBERON:0018118 polyA plus RNA-seq      .
# 370  UBERON:0036149 gtex Skin_Not_Sun_Exposed_Supra...      .
#
#             Assay title  ontology_curie                   biosample_name  \
# 0    polyA plus RNA-seq      CL:0000047               neuronal stem cell
# 1         total RNA-seq      CL:0000062                       osteoblast
# 2    polyA plus RNA-seq      CL:0000084                           T-cell
# 3         total RNA-seq      CL:0000084                           T-cell
# 4         total RNA-seq      CL:0000115                 endothelial cell
# ..                  ...             ...                              ...
# 366  polyA plus RNA-seq  UBERON:0018115                left renal pelvis
# 367  polyA plus RNA-seq  UBERON:0018116               right renal pelvis
# 368  polyA plus RNA-seq  UBERON:0018117   left renal cortex interstitium
# 369  polyA plus RNA-seq  UBERON:0018118  right renal cortex interstitium
# 370  polyA plus RNA-seq  UBERON:0036149                  suprapubic skin
#
#                     biosample_type biosample_life_stage  \
# 0    in_vitro_differentiated_cells            embryonic
# 1                     primary_cell                adult
# 2                     primary_cell                adult
# 3                     primary_cell                adult
# 4    in_vitro_differentiated_cells                adult
# ..                             ...                  ...
# 366                         tissue            embryonic
# 367                         tissue            embryonic
# 368                         tissue            embryonic
# 369                         tissue            embryonic
# 370                         tissue                adult
#
#                          gtex_tissue data_source endedness  \
# 0                                         encode    paired
# 1                                         encode    paired
# 2                                         encode    paired
# 3                                         encode    single
# 4                                         encode    single
# ..                               ...         ...       ...
# 366                                       encode    single
# 367                                       encode    single
# 368                                       encode    single
# 369                                       encode    single
# 370  Skin_Not_Sun_Exposed_Suprapubic        gtex    paired
#
#      genetically_modified  nonzero_mean
# 0                   False      0.143617
# 1                   False      0.094144
# 2                   False      0.124296
# 3                   False      0.100934
# 4                   False      0.135553
# ..                    ...           ...
# 366                 False      0.268222
# 367                 False      0.258522
# 368                 False      0.215190
# 369                 False      0.365676
# 370                 False      0.045404
#
# [371 rows x 12 columns]

# %% [markdown]
# Some handy additional metadata can be found in `.uns`:

# %%
print(f'Interval: {variant_scores.uns["interval"]}')
print(f'Variant: {variant_scores.uns["variant"]}')
print(f'Variant scorer: {variant_scores.uns["variant_scorer"]}')
# Out:
# Interval: chr11:27169243-28217819:.
# Variant: chr11:27693531:C>T
# Variant scorer: GeneMaskLFCScorer(requested_output=RNA_SEQ)

# %% [markdown]
# We recommend interacting with variant scores by flattening `AnnData` objects
# using `tidy_scores`, which produces a dataframe with each row being a single
# score for each combination of (variant, gene, scorer, ontology). It optionally
# excludes stranded tracks which do not match the gene’s strand for gene-specific
# scorer.
#
# The `raw_score` column contains the same values as stored in `variant_scores.X`.
# The `quantile_score` column is the rank of the `raw_score` in the distribution
# of scores for a background set of common variants, represented as a quantile
# probability. This allows for direct comparison across variant scoring strategies
# that yield scores on different scales. See
# [FAQs](https://www.alphagenomedocs.com/faqs.html#what-is-the-difference-between-a-quantile-score-and-raw-score)
# for further details.

# %%
variant_scorers.tidy_scores([variant_scores], match_gene_strand=True)
# Out:
#               variant_id            scored_interval          gene_id  \
# 0     chr11:27693531:C>T  chr11:27169243-28217819:.  ENSG00000109881
# 1     chr11:27693531:C>T  chr11:27169243-28217819:.  ENSG00000109881
# 2     chr11:27693531:C>T  chr11:27169243-28217819:.  ENSG00000109881
# 3     chr11:27693531:C>T  chr11:27169243-28217819:.  ENSG00000109881
# 4     chr11:27693531:C>T  chr11:27169243-28217819:.  ENSG00000109881
# ...                  ...                        ...              ...
# 7415  chr11:27693531:C>T  chr11:27169243-28217819:.  ENSG00000278483
# 7416  chr11:27693531:C>T  chr11:27169243-28217819:.  ENSG00000278483
# 7417  chr11:27693531:C>T  chr11:27169243-28217819:.  ENSG00000278483
# 7418  chr11:27693531:C>T  chr11:27169243-28217819:.  ENSG00000278483
# 7419  chr11:27693531:C>T  chr11:27169243-28217819:.  ENSG00000278483
#
#      gene_name       gene_type gene_strand junction_Start junction_End  \
# 0       CCDC34  protein_coding           -           None         None
# 1       CCDC34  protein_coding           -           None         None
# 2       CCDC34  protein_coding           -           None         None
# 3       CCDC34  protein_coding           -           None         None
# 4       CCDC34  protein_coding           -           None         None
# ...        ...             ...         ...            ...          ...
# 7415   MIR8087           miRNA           -           None         None
# 7416   MIR8087           miRNA           -           None         None
# 7417   MIR8087           miRNA           -           None         None
# 7418   MIR8087           miRNA           -           None         None
# 7419   MIR8087           miRNA           -           None         None
#
#      output_type                               variant_scorer  ...  \
# 0        RNA_SEQ  GeneMaskLFCScorer(requested_output=RNA_SEQ)  ...
# 1        RNA_SEQ  GeneMaskLFCScorer(requested_output=RNA_SEQ)  ...
# 2        RNA_SEQ  GeneMaskLFCScorer(requested_output=RNA_SEQ)  ...
# 3        RNA_SEQ  GeneMaskLFCScorer(requested_output=RNA_SEQ)  ...
# 4        RNA_SEQ  GeneMaskLFCScorer(requested_output=RNA_SEQ)  ...
# ...          ...                                          ...  ...
# 7415     RNA_SEQ  GeneMaskLFCScorer(requested_output=RNA_SEQ)  ...
# 7416     RNA_SEQ  GeneMaskLFCScorer(requested_output=RNA_SEQ)  ...
# 7417     RNA_SEQ  GeneMaskLFCScorer(requested_output=RNA_SEQ)  ...
# 7418     RNA_SEQ  GeneMaskLFCScorer(requested_output=RNA_SEQ)  ...
# 7419     RNA_SEQ  GeneMaskLFCScorer(requested_output=RNA_SEQ)  ...
#
#       ontology_curie                   biosample_name  \
# 0         CL:0000047               neuronal stem cell
# 1         CL:0000062                       osteoblast
# 2         CL:0000084                           T-cell
# 3         CL:0000084                           T-cell
# 4         CL:0000115                 endothelial cell
# ...              ...                              ...
# 7415  UBERON:0018115                left renal pelvis
# 7416  UBERON:0018116               right renal pelvis
# 7417  UBERON:0018117   left renal cortex interstitium
# 7418  UBERON:0018118  right renal cortex interstitium
# 7419  UBERON:0036149                  suprapubic skin
#
#                      biosample_type biosample_life_stage  \
# 0     in_vitro_differentiated_cells            embryonic
# 1                      primary_cell                adult
# 2                      primary_cell                adult
# 3                      primary_cell                adult
# 4     in_vitro_differentiated_cells                adult
# ...                             ...                  ...
# 7415                         tissue            embryonic
# 7416                         tissue            embryonic
# 7417                         tissue            embryonic
# 7418                         tissue            embryonic
# 7419                         tissue                adult
#
#                           gtex_tissue data_source endedness  \
# 0                                          encode    paired
# 1                                          encode    paired
# 2                                          encode    paired
# 3                                          encode    single
# 4                                          encode    single
# ...                               ...         ...       ...
# 7415                                       encode    single
# 7416                                       encode    single
# 7417                                       encode    single
# 7418                                       encode    single
# 7419  Skin_Not_Sun_Exposed_Suprapubic        gtex    paired
#
#      genetically_modified raw_score quantile_score
# 0                   False  0.001065       0.698293
# 1                   False -0.002522      -0.925530
# 2                   False -0.004104      -0.956008
# 3                   False -0.003904      -0.954527
# 4                   False -0.000563      -0.531989
# ...                   ...       ...            ...
# 7415                False  0.005394       0.980249
# 7416                False  0.002445       0.867120
# 7417                False  0.000733       0.507261
# 7418                False  0.003930       0.946357
# 7419                False -0.000252      -0.232817
#
# [7420 rows x 23 columns]

# %%
tidy = variant_scorers.tidy_scores([variant_scores], match_gene_strand=True)

# %%
bdnf = tidy[tidy["gene_name"] == "BDNF"]
bdnf
# Out:
#               variant_id            scored_interval          gene_id  \
# 1484  chr11:27693531:C>T  chr11:27169243-28217819:.  ENSG00000176697
# 1485  chr11:27693531:C>T  chr11:27169243-28217819:.  ENSG00000176697
# 1486  chr11:27693531:C>T  chr11:27169243-28217819:.  ENSG00000176697
# 1487  chr11:27693531:C>T  chr11:27169243-28217819:.  ENSG00000176697
# 1488  chr11:27693531:C>T  chr11:27169243-28217819:.  ENSG00000176697
# ...                  ...                        ...              ...
# 1850  chr11:27693531:C>T  chr11:27169243-28217819:.  ENSG00000176697
# 1851  chr11:27693531:C>T  chr11:27169243-28217819:.  ENSG00000176697
# 1852  chr11:27693531:C>T  chr11:27169243-28217819:.  ENSG00000176697
# 1853  chr11:27693531:C>T  chr11:27169243-28217819:.  ENSG00000176697
# 1854  chr11:27693531:C>T  chr11:27169243-28217819:.  ENSG00000176697
#
#      gene_name       gene_type gene_strand junction_Start junction_End  \
# 1484      BDNF  protein_coding           -           None         None
# 1485      BDNF  protein_coding           -           None         None
# 1486      BDNF  protein_coding           -           None         None
# 1487      BDNF  protein_coding           -           None         None
# 1488      BDNF  protein_coding           -           None         None
# ...        ...             ...         ...            ...          ...
# 1850      BDNF  protein_coding           -           None         None
# 1851      BDNF  protein_coding           -           None         None
# 1852      BDNF  protein_coding           -           None         None
# 1853      BDNF  protein_coding           -           None         None
# 1854      BDNF  protein_coding           -           None         None
#
#      output_type                               variant_scorer  ...  \
# 1484     RNA_SEQ  GeneMaskLFCScorer(requested_output=RNA_SEQ)  ...
# 1485     RNA_SEQ  GeneMaskLFCScorer(requested_output=RNA_SEQ)  ...
# 1486     RNA_SEQ  GeneMaskLFCScorer(requested_output=RNA_SEQ)  ...
# 1487     RNA_SEQ  GeneMaskLFCScorer(requested_output=RNA_SEQ)  ...
# 1488     RNA_SEQ  GeneMaskLFCScorer(requested_output=RNA_SEQ)  ...
# ...          ...                                          ...  ...
# 1850     RNA_SEQ  GeneMaskLFCScorer(requested_output=RNA_SEQ)  ...
# 1851     RNA_SEQ  GeneMaskLFCScorer(requested_output=RNA_SEQ)  ...
# 1852     RNA_SEQ  GeneMaskLFCScorer(requested_output=RNA_SEQ)  ...
# 1853     RNA_SEQ  GeneMaskLFCScorer(requested_output=RNA_SEQ)  ...
# 1854     RNA_SEQ  GeneMaskLFCScorer(requested_output=RNA_SEQ)  ...
#
#       ontology_curie                   biosample_name  \
# 1484      CL:0000047               neuronal stem cell
# 1485      CL:0000062                       osteoblast
# 1486      CL:0000084                           T-cell
# 1487      CL:0000084                           T-cell
# 1488      CL:0000115                 endothelial cell
# ...              ...                              ...
# 1850  UBERON:0018115                left renal pelvis
# 1851  UBERON:0018116               right renal pelvis
# 1852  UBERON:0018117   left renal cortex interstitium
# 1853  UBERON:0018118  right renal cortex interstitium
# 1854  UBERON:0036149                  suprapubic skin
#
#                      biosample_type biosample_life_stage  \
# 1484  in_vitro_differentiated_cells            embryonic
# 1485                   primary_cell                adult
# 1486                   primary_cell                adult
# 1487                   primary_cell                adult
# 1488  in_vitro_differentiated_cells                adult
# ...                             ...                  ...
# 1850                         tissue            embryonic
# 1851                         tissue            embryonic
# 1852                         tissue            embryonic
# 1853                         tissue            embryonic
# 1854                         tissue                adult
#
#                           gtex_tissue data_source endedness  \
# 1484                                       encode    paired
# 1485                                       encode    paired
# 1486                                       encode    paired
# 1487                                       encode    single
# 1488                                       encode    single
# ...                               ...         ...       ...
# 1850                                       encode    single
# 1851                                       encode    single
# 1852                                       encode    single
# 1853                                       encode    single
# 1854  Skin_Not_Sun_Exposed_Suprapubic        gtex    paired
#
#      genetically_modified raw_score quantile_score
# 1484                False -0.003707      -0.948098
# 1485                False -0.005503      -0.990578
# 1486                False -0.003092      -0.917890
# 1487                False -0.002973      -0.917890
# 1488                False -0.006333      -0.992560
# ...                   ...       ...            ...
# 1850                False -0.006093      -0.985885
# 1851                False -0.004724      -0.968451
# 1852                False -0.004448      -0.962736
# 1853                False -0.005095      -0.972395
# 1854                False -0.015530      -0.998320
#
# [371 rows x 23 columns]

# %%
PD_relevant = [
    "substantia nigra",
    "caudate nucleus",
    "putamen",
    "nucleus accumbens",
    "brain",
    "frontal cortex",
    "anterior cingulate cortex",
    "dorsolateral prefrontal cortex",
    "hypothalamus",
    "amygdala",
    "Ammon's horn",
    "astrocyte",
    "glutamatergic neuron",
    "neural cell",
    "spinal cord"]

# %%
bdnf_pdRelevant = bdnf[bdnf["biosample_name"].isin(PD_relevant)]
bdnf_pdRelevant
# Out:
#               variant_id            scored_interval          gene_id  \
# 1489  chr11:27693531:C>T  chr11:27169243-28217819:.  ENSG00000176697
# 1515  chr11:27693531:C>T  chr11:27169243-28217819:.  ENSG00000176697
# 1529  chr11:27693531:C>T  chr11:27169243-28217819:.  ENSG00000176697
# 1668  chr11:27693531:C>T  chr11:27169243-28217819:.  ENSG00000176697
# 1694  chr11:27693531:C>T  chr11:27169243-28217819:.  ENSG00000176697
# 1726  chr11:27693531:C>T  chr11:27169243-28217819:.  ENSG00000176697
# 1727  chr11:27693531:C>T  chr11:27169243-28217819:.  ENSG00000176697
# 1749  chr11:27693531:C>T  chr11:27169243-28217819:.  ENSG00000176697
# 1810  chr11:27693531:C>T  chr11:27169243-28217819:.  ENSG00000176697
# 1811  chr11:27693531:C>T  chr11:27169243-28217819:.  ENSG00000176697
# 1812  chr11:27693531:C>T  chr11:27169243-28217819:.  ENSG00000176697
# 1813  chr11:27693531:C>T  chr11:27169243-28217819:.  ENSG00000176697
# 1814  chr11:27693531:C>T  chr11:27169243-28217819:.  ENSG00000176697
# 1815  chr11:27693531:C>T  chr11:27169243-28217819:.  ENSG00000176697
# 1816  chr11:27693531:C>T  chr11:27169243-28217819:.  ENSG00000176697
# 1818  chr11:27693531:C>T  chr11:27169243-28217819:.  ENSG00000176697
# 1844  chr11:27693531:C>T  chr11:27169243-28217819:.  ENSG00000176697
# 1845  chr11:27693531:C>T  chr11:27169243-28217819:.  ENSG00000176697
#
#      gene_name       gene_type gene_strand junction_Start junction_End  \
# 1489      BDNF  protein_coding           -           None         None
# 1515      BDNF  protein_coding           -           None         None
# 1529      BDNF  protein_coding           -           None         None
# 1668      BDNF  protein_coding           -           None         None
# 1694      BDNF  protein_coding           -           None         None
# 1726      BDNF  protein_coding           -           None         None
# 1727      BDNF  protein_coding           -           None         None
# 1749      BDNF  protein_coding           -           None         None
# 1810      BDNF  protein_coding           -           None         None
# 1811      BDNF  protein_coding           -           None         None
# 1812      BDNF  protein_coding           -           None         None
# 1813      BDNF  protein_coding           -           None         None
# 1814      BDNF  protein_coding           -           None         None
# 1815      BDNF  protein_coding           -           None         None
# 1816      BDNF  protein_coding           -           None         None
# 1818      BDNF  protein_coding           -           None         None
# 1844      BDNF  protein_coding           -           None         None
# 1845      BDNF  protein_coding           -           None         None
#
#      output_type                               variant_scorer  ...  \
# 1489     RNA_SEQ  GeneMaskLFCScorer(requested_output=RNA_SEQ)  ...
# 1515     RNA_SEQ  GeneMaskLFCScorer(requested_output=RNA_SEQ)  ...
# 1529     RNA_SEQ  GeneMaskLFCScorer(requested_output=RNA_SEQ)  ...
# 1668     RNA_SEQ  GeneMaskLFCScorer(requested_output=RNA_SEQ)  ...
# 1694     RNA_SEQ  GeneMaskLFCScorer(requested_output=RNA_SEQ)  ...
# 1726     RNA_SEQ  GeneMaskLFCScorer(requested_output=RNA_SEQ)  ...
# 1727     RNA_SEQ  GeneMaskLFCScorer(requested_output=RNA_SEQ)  ...
# 1749     RNA_SEQ  GeneMaskLFCScorer(requested_output=RNA_SEQ)  ...
# 1810     RNA_SEQ  GeneMaskLFCScorer(requested_output=RNA_SEQ)  ...
# 1811     RNA_SEQ  GeneMaskLFCScorer(requested_output=RNA_SEQ)  ...
# 1812     RNA_SEQ  GeneMaskLFCScorer(requested_output=RNA_SEQ)  ...
# 1813     RNA_SEQ  GeneMaskLFCScorer(requested_output=RNA_SEQ)  ...
# 1814     RNA_SEQ  GeneMaskLFCScorer(requested_output=RNA_SEQ)  ...
# 1815     RNA_SEQ  GeneMaskLFCScorer(requested_output=RNA_SEQ)  ...
# 1816     RNA_SEQ  GeneMaskLFCScorer(requested_output=RNA_SEQ)  ...
# 1818     RNA_SEQ  GeneMaskLFCScorer(requested_output=RNA_SEQ)  ...
# 1844     RNA_SEQ  GeneMaskLFCScorer(requested_output=RNA_SEQ)  ...
# 1845     RNA_SEQ  GeneMaskLFCScorer(requested_output=RNA_SEQ)  ...
#
#       ontology_curie                  biosample_name  \
# 1489      CL:0000127                       astrocyte
# 1515      CL:0000679            glutamatergic neuron
# 1529      CL:0002319                     neural cell
# 1668  UBERON:0000955                           brain
# 1694  UBERON:0001870                  frontal cortex
# 1726  UBERON:0002240                     spinal cord
# 1727  UBERON:0002240                     spinal cord
# 1749  UBERON:0009834  dorsolateral prefrontal cortex
# 1810  UBERON:0001870                  frontal cortex
# 1811  UBERON:0001873                 caudate nucleus
# 1812  UBERON:0001874                         putamen
# 1813  UBERON:0001876                        amygdala
# 1814  UBERON:0001882               nucleus accumbens
# 1815  UBERON:0001898                    hypothalamus
# 1816  UBERON:0001954                    Ammon's horn
# 1818  UBERON:0002038                substantia nigra
# 1844  UBERON:0009834  dorsolateral prefrontal cortex
# 1845  UBERON:0009835       anterior cingulate cortex
#
#                      biosample_type biosample_life_stage  \
# 1489                   primary_cell              unknown
# 1515  in_vitro_differentiated_cells                adult
# 1529  in_vitro_differentiated_cells            embryonic
# 1668                         tissue                adult
# 1694                         tissue            embryonic
# 1726                         tissue            embryonic
# 1727                         tissue            embryonic
# 1749                         tissue                adult
# 1810                         tissue                adult
# 1811                         tissue                adult
# 1812                         tissue                adult
# 1813                         tissue                adult
# 1814                         tissue                adult
# 1815                         tissue                adult
# 1816                         tissue                adult
# 1818                         tissue                adult
# 1844                         tissue                adult
# 1845                         tissue                adult
#
#                                 gtex_tissue data_source endedness  \
# 1489                                             encode    paired
# 1515                                             encode    single
# 1529                                             encode    paired
# 1668                                             encode    paired
# 1694                                             encode    paired
# 1726                                             encode    paired
# 1727                                             encode    paired
# 1749                                             encode    single
# 1810                           Brain_Cortex        gtex    paired
# 1811            Brain_Caudate_basal_ganglia        gtex    paired
# 1812            Brain_Putamen_basal_ganglia        gtex    paired
# 1813                         Brain_Amygdala        gtex    paired
# 1814  Brain_Nucleus_accumbens_basal_ganglia        gtex    paired
# 1815                     Brain_Hypothalamus        gtex    paired
# 1816                      Brain_Hippocampus        gtex    paired
# 1818                 Brain_Substantia_nigra        gtex    paired
# 1844               Brain_Frontal_Cortex_BA9        gtex    paired
# 1845   Brain_Anterior_cingulate_cortex_BA24        gtex    paired
#
#      genetically_modified raw_score quantile_score
# 1489                False -0.006642      -0.993716
# 1515                False  0.005755       0.989218
# 1529                False  0.002568       0.886654
# 1668                False  0.006778       0.989576
# 1694                False  0.002910       0.942704
# 1726                False -0.003505      -0.954527
# 1727                False -0.001490      -0.806896
# 1749                False  0.005658       0.988467
# 1810                False  0.006080       0.986352
# 1811                False  0.004320       0.958831
# 1812                False  0.004384       0.958831
# 1813                False  0.005769       0.982141
# 1814                False  0.005184       0.975029
# 1815                False  0.006311       0.986804
# 1816                False  0.006260       0.986352
# 1818                False  0.005355       0.977415
# 1844                False  0.006763       0.989218
# 1845                False  0.006486       0.987663
#
# [18 rows x 23 columns]

# %%
biosample = bdnf_pdRelevant["ontology_curie"]

# %% [markdown]
# ## Highlighting important regions with *in silico* mutagenesis
#
# To highlight which regions in a DNA sequence are functionally important for a
# final variant prediction, we can perform an **in silico mutagenesis** (ISM)
# analysis by scoring all possible single nucleotide variants in a specific
# interval.
#
# Here is a visual overview of this process:
#
# <a href="https://services.google.com/fh/files/misc/ism_green_v2.png"><img src="https://services.google.com/fh/files/misc/ism_green_v2.png" alt="ISM" border="0" height=500></a>

# %% [markdown]
# We define an `ism_interval`, which is a relatively small region of DNA that we
# want to systematically mutate. We also define the `sequence_interval`, which is
# the contextual interval the model will use when making predictions for each
# variant.

# %%
# 16KB DNA sequence to use as context when making predictions.
sequence_interval = genome.Interval('chr11', 27_685_531, 27_701_531)
sequence_interval = sequence_interval.resize(dna_client.SEQUENCE_LENGTH_16KB)

# Mutate all bases in the central 256-base region of the sequence_interval.
ism_interval = sequence_interval.resize(256)

# %% [markdown]
# Next, we define the scorer we want to use to score each of the ISM variants.
# Here, we use a center mask scorer on predicted `DNASE` values, which will score
# each variant's effect on DNA accessibility in the 500bp vicinity. See the
# [variant scoring documentation](https://www.alphagenomedocs.com/variant_scoring.html)
# for more information on variant scoring.

# %%
dnase_variant_scorer = variant_scorers.CenterMaskScorer(
    requested_output=dna_client.OutputType.DNASE,
    width=501,
    aggregation_type=variant_scorers.AggregationType.DIFF_MEAN,
)

# %% [markdown]
# Finally, we can use `score_variants` (notice the plural s) to score all
# variants.
#
# Note that this operation is quite expensive. For speed reasons, we recommend
# using shorter input sequences for the contextual `sequence_interval` and
# narrower `ism_interval` regions to mutate if possible.

# %%
variant_scores = dna_model.score_ism_variants(
    interval=sequence_interval,
    ism_interval=ism_interval,
    variant_scorers=[dnase_variant_scorer],
)
# Out:
#   0%|          | 0/26 [00:00<?, ?it/s]

# %% [markdown]
# The length of the returned `variant_scores` is 768, since we scored 768 variants
# (256 positions * 3 alternative bases per position):

# %%
len(variant_scores)
# Out:
# 768

# %% [markdown]
# Each variant has scores of shape `(1, 305)`, reflecting the fact that we are not
# using a gene-centric scorer and that there are 305 `DNASE` tracks:

# %%
# Index into first variant and first scorer.
variant_scores[0][0].X.shape
# Out:
# (1, 305)

# %%
variant_scores[0][0].var
# Out:
#                          name strand Assay title  ontology_curie  \
# 0        CL:0000047 DNase-seq      .   DNase-seq      CL:0000047
# 1        CL:0000084 DNase-seq      .   DNase-seq      CL:0000084
# 2        CL:0000115 DNase-seq      .   DNase-seq      CL:0000115
# 3        CL:0000127 DNase-seq      .   DNase-seq      CL:0000127
# 4        CL:0000134 DNase-seq      .   DNase-seq      CL:0000134
# ..                        ...    ...         ...             ...
# 300  UBERON:0036149 DNase-seq      .   DNase-seq  UBERON:0036149
# 301  UBERON:8300001 DNase-seq      .   DNase-seq  UBERON:8300001
# 302  UBERON:8300002 DNase-seq      .   DNase-seq  UBERON:8300002
# 303  UBERON:8300003 DNase-seq      .   DNase-seq  UBERON:8300003
# 304  UBERON:8300004 DNase-seq      .   DNase-seq  UBERON:8300004
#
#             biosample_name                 biosample_type  \
# 0       neuronal stem cell  in_vitro_differentiated_cells
# 1                   T-cell                   primary_cell
# 2         endothelial cell  in_vitro_differentiated_cells
# 3                astrocyte                   primary_cell
# 4    mesenchymal stem cell  in_vitro_differentiated_cells
# ..                     ...                            ...
# 300        suprapubic skin                         tissue
# 301         right forelimb                         tissue
# 302          left forelimb                         tissue
# 303         right hindlimb                         tissue
# 304          left hindlimb                         tissue
#
#     biosample_life_stage data_source endedness  genetically_modified  \
# 0              embryonic      encode    single                 False
# 1                  adult      encode    paired                 False
# 2                  adult      encode    paired                 False
# 3                unknown      encode    single                 False
# 4              embryonic      encode    paired                 False
# ..                   ...         ...       ...                   ...
# 300                adult      encode    paired                 False
# 301            embryonic      encode    paired                 False
# 302            embryonic      encode    paired                 False
# 303            embryonic      encode    paired                 False
# 304            embryonic      encode    paired                 False
#
#      nonzero_mean
# 0        1.554501
# 1        0.151404
# 2        0.513028
# 3        0.845752
# 4        0.540044
# ..            ...
# 300      0.485925
# 301      1.431965
# 302      1.206352
# 303      1.254712
# 304      1.946842
#
# [305 rows x 11 columns]

# %% [markdown]
# To understand which positions are most influential in the predictions, we can
# visualize these scores using a sequence logo. This requires summarizing the
# scores into a single scalar value per variant.
#
# As an example, let's extract the DNASE score for just the K562 cell line, a
# widely used experimental model. Alternatively, you could average across multiple
# tissues to obtain a single scalar value.

# %%
def extract_SN(adata):
  values = adata.X[:, adata.var['ontology_curie'] == 'UBERON:0002038']
  assert values.size == 1
  return values.flatten()[0]


ism_result = ism.ism_matrix(
    [extract_SN(x[0]) for x in variant_scores],
    variants=[v[0].uns['variant'] for v in variant_scores],
)
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# /tmp/ipykernel_1852/1550264728.py in <cell line: 0>()
#       6
#       7 ism_result = ism.ism_matrix(
# ----> 8     [extract_SN(x[0]) for x in variant_scores],
#       9     variants=[v[0].uns['variant'] for v in variant_scores],
#      10 )
#
# /tmp/ipykernel_1852/1550264728.py in extract_SN(adata)
#       1 def extract_SN(adata):
#       2   values = adata.X[:, adata.var['ontology_curie'] == 'UBERON:0002038']
# ----> 3   assert values.size == 1
#       4   return values.flatten()[0]
#       5
#
# AssertionError:

# %% [markdown]
# The shape of `ism_result` is `(256, 4`) since we have 1 score per position per
# each of the 4 DNA bases.
#
# Note that in this case, our call to `ism.ism_matrix()` had the argument
# `multiply_by_sequence` set to 'True', so the output array contains non-zero
# values only for the bases corresponding to the reference sequence.

# %%
ism_result.shape
# Out:
# (256, 4)

# %% [markdown]
# Finally, we plot the contribution scores as a sequence logo:

# %%
plot_components.plot(
    [
        plot_components.SeqLogo(
            scores=ism_result,
            scores_interval=ism_interval,
            ylabel='ISM K562 DNase',
        )
    ],
    interval=ism_interval,
    fig_width=35,
)

plt.show()

# %% [markdown]
# This plot shows that the sequence between positions ~225 to ~240 has the
# strongest effect on predicted nearby DNAse in K562 cells.
#
# These contribution scores can be used to systematically discover motifs
# important for different modalities and cell types, find the transcription
# factors binding those motifs and map motif instances across the genome. Here are
# a few tools you can use to do this: -
# [tfmodisco-lite](https://github.com/jmschrei/tfmodisco-lite/) -
# [tangermeme](https://github.com/jmschrei/tangermeme) -
# [tomtom](https://meme-suite.org/meme/tools/tomtom)

# %% [markdown]
# ## Making mouse predictions

# %% [markdown]
# So far, this notebook has focused on predictions for human
# (`Organism.HOMO_SAPIENS`). To generate predictions for mouse, specify the
# organism as `Organism.MUS_MUSCULUS` instead. Please note that the supported
# ontology terms differ between species.
#
# The following example demonstrates how to call `predict_sequence` for mouse
# predictions:

# %%
output = dna_model.predict_sequence(
    sequence='GATTACA'.center(
        dna_client.SEQUENCE_LENGTH_1MB, 'N'
    ),  # Pad to valid sequence length.
    organism=dna_client.Organism.MUS_MUSCULUS,
    requested_outputs=[dna_client.OutputType.DNASE],
    ontology_terms=['UBERON:0002048'],  # Lung.
)

# %% [markdown]
# And here is an example of calling `predict_interval` for a mouse genomic
# interval:

# %%
interval = genome.Interval('chr1', 3_000_000, 3_000_001).resize(
    dna_client.SEQUENCE_LENGTH_1MB
)

output = dna_model.predict_interval(
    interval=interval,
    organism=dna_client.Organism.MUS_MUSCULUS,
    requested_outputs=[dna_client.OutputType.RNA_SEQ],
    ontology_terms=['UBERON:0002048'],  # Lung.
)

output.rna_seq.values.shape
# Out:
# (1048576, 3)

# %% [markdown]
# ## Conclusion
#
# That's it for the quick start guide. To dive in further, check out our
# [other tutorials](https://www.alphagenomedocs.com/tutorials/index.html).
